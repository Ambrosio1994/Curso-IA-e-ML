# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.datasets import mnist
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Input

# %%
(x_train, _), (x_test, _) = mnist.load_data()

# %%
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# %%
x_train = x_train.reshape((-1, 784))
x_test = x_test.reshape((-1, 784))

# %%
model = Sequential()

model.add(Dense(128, activation = 'relu', input_dim = x_train.shape[1]))

model.add(Dense(x_train.shape[1], activation = 'sigmoid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               100480
#
#  dense_1 (Dense)             (None, 784)               101136
#
# =================================================================
# Total params: 201616 (787.56 KB)
# Trainable params: 201616 (787.56 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['accuracy'])

model.fit(x_train, x_train, epochs=50, batch_size=256, validation_data=(x_test, x_test))
# Out:
# Epoch 1/50
# 235/235 [==============================] - 4s 11ms/step - loss: 0.0503 - accuracy: 0.0119 - val_loss: 0.0245 - val_accuracy: 0.0105
# Epoch 2/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0187 - accuracy: 0.0107 - val_loss: 0.0136 - val_accuracy: 0.0114
# Epoch 3/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0113 - accuracy: 0.0121 - val_loss: 0.0089 - val_accuracy: 0.0131
# Epoch 4/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0078 - accuracy: 0.0125 - val_loss: 0.0064 - val_accuracy: 0.0130
# Epoch 5/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0059 - accuracy: 0.0134 - val_loss: 0.0051 - val_accuracy: 0.0137
# Epoch 6/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0049 - accuracy: 0.0135 - val_loss: 0.0043 - val_accuracy: 0.0143
# Epoch 7/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0042 - accuracy: 0.0135 - val_loss: 0.0038 - val_accuracy: 0.0128
# Epoch 8/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0037 - accuracy: 0.0141 - val_loss: 0.0034 - val_accuracy: 0.0129
# Epoch 9/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0034 - accuracy: 0.0138 - val_loss: 0.0031 - val_accuracy: 0.0138
# Epoch 10/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0031 - accuracy: 0.0133 - val_loss: 0.0029 - val_accuracy: 0.0135
# Epoch 11/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0029 - accuracy: 0.0142 - val_loss: 0.0027 - val_accuracy: 0.0152
# Epoch 12/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0027 - accuracy: 0.0140 - val_loss: 0.0026 - val_accuracy: 0.0146
# Epoch 13/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0026 - accuracy: 0.0137 - val_loss: 0.0025 - val_accuracy: 0.0141
# Epoch 14/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0025 - accuracy: 0.0138 - val_loss: 0.0024 - val_accuracy: 0.0147
# Epoch 15/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0024 - accuracy: 0.0140 - val_loss: 0.0023 - val_accuracy: 0.0142
# Epoch 16/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0023 - accuracy: 0.0139 - val_loss: 0.0022 - val_accuracy: 0.0143
# Epoch 17/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0022 - accuracy: 0.0143 - val_loss: 0.0022 - val_accuracy: 0.0140
# Epoch 18/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0022 - accuracy: 0.0145 - val_loss: 0.0021 - val_accuracy: 0.0149
# Epoch 19/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0021 - accuracy: 0.0142 - val_loss: 0.0020 - val_accuracy: 0.0152
# Epoch 20/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0021 - accuracy: 0.0137 - val_loss: 0.0020 - val_accuracy: 0.0152
# Epoch 21/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0020 - accuracy: 0.0141 - val_loss: 0.0020 - val_accuracy: 0.0146
# Epoch 22/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0020 - accuracy: 0.0144 - val_loss: 0.0019 - val_accuracy: 0.0149
# Epoch 23/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0019 - accuracy: 0.0146 - val_loss: 0.0019 - val_accuracy: 0.0152
# Epoch 24/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0019 - accuracy: 0.0147 - val_loss: 0.0019 - val_accuracy: 0.0154
# Epoch 25/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0019 - accuracy: 0.0150 - val_loss: 0.0019 - val_accuracy: 0.0141
# Epoch 26/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0019 - accuracy: 0.0145 - val_loss: 0.0018 - val_accuracy: 0.0162
# Epoch 27/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0018 - accuracy: 0.0151 - val_loss: 0.0018 - val_accuracy: 0.0149
# Epoch 28/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0018 - accuracy: 0.0149 - val_loss: 0.0018 - val_accuracy: 0.0149
# Epoch 29/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0018 - accuracy: 0.0146 - val_loss: 0.0018 - val_accuracy: 0.0158
# Epoch 30/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0018 - accuracy: 0.0148 - val_loss: 0.0018 - val_accuracy: 0.0159
# Epoch 31/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0018 - accuracy: 0.0149 - val_loss: 0.0018 - val_accuracy: 0.0151
# Epoch 32/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0018 - accuracy: 0.0153 - val_loss: 0.0017 - val_accuracy: 0.0158
# Epoch 33/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0017 - accuracy: 0.0145 - val_loss: 0.0017 - val_accuracy: 0.0158
# Epoch 34/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0017 - accuracy: 0.0151 - val_loss: 0.0017 - val_accuracy: 0.0167
# Epoch 35/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0017 - accuracy: 0.0146 - val_loss: 0.0017 - val_accuracy: 0.0161
# Epoch 36/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0017 - accuracy: 0.0147 - val_loss: 0.0017 - val_accuracy: 0.0159
# Epoch 37/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0017 - accuracy: 0.0150 - val_loss: 0.0017 - val_accuracy: 0.0164
# Epoch 38/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0017 - accuracy: 0.0149 - val_loss: 0.0017 - val_accuracy: 0.0153
# Epoch 39/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0017 - accuracy: 0.0154 - val_loss: 0.0017 - val_accuracy: 0.0158
# Epoch 40/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0017 - accuracy: 0.0148 - val_loss: 0.0017 - val_accuracy: 0.0156
# Epoch 41/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0017 - accuracy: 0.0154 - val_loss: 0.0017 - val_accuracy: 0.0146
# Epoch 42/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0017 - accuracy: 0.0144 - val_loss: 0.0017 - val_accuracy: 0.0165
# Epoch 43/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0016 - accuracy: 0.0151 - val_loss: 0.0016 - val_accuracy: 0.0155
# Epoch 44/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0016 - accuracy: 0.0148 - val_loss: 0.0016 - val_accuracy: 0.0161
# Epoch 45/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0016 - accuracy: 0.0151 - val_loss: 0.0016 - val_accuracy: 0.0163
# Epoch 46/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0016 - accuracy: 0.0150 - val_loss: 0.0016 - val_accuracy: 0.0156
# Epoch 47/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0016 - accuracy: 0.0153 - val_loss: 0.0016 - val_accuracy: 0.0160
# Epoch 48/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0016 - accuracy: 0.0152 - val_loss: 0.0016 - val_accuracy: 0.0152
# Epoch 49/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0016 - accuracy: 0.0152 - val_loss: 0.0016 - val_accuracy: 0.0162
# Epoch 50/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0016 - accuracy: 0.0151 - val_loss: 0.0016 - val_accuracy: 0.0152

# %%
dimensao = Input(shape = (x_train.shape[1],))
camada_encododer = model.layers[0]
encoder = Model(dimensao, camada_encododer(dimensao))
encoder.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 784)]             0
#
#  dense (Dense)               (None, 128)               100480
#
# =================================================================
# Total params: 100480 (392.50 KB)
# Trainable params: 100480 (392.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
imagens_cod = encoder.predict(x_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %%
imagens_decod = model.predict(x_test)
# Out:
# 313/313 [==============================] - 1s 3ms/step

# %%
imagens = 10
imagens_test = np.random.choice(x_test.shape[0], size=imagens)

# %%
plt.figure(figsize=(28 ,28))

for i, indice_imagem in enumerate(imagens_test):
    # Imagens Originais
    eixo = plt.subplot(10, 10, i + 1)
    plt.imshow(x_test[indice_imagem].reshape(28, 28))
    plt.title('Imagem Original')
    plt.xticks(())
    plt.yticks(())

    # Imagens Codificadas
    eixo = plt.subplot(10, 10, i + imagens)
    plt.imshow(imagens_cod[indice_imagem].reshape(16, 8))
    plt.title('Imagem Codifificada')
    plt.xticks(())
    plt.yticks(())

    # Imagens decodificadas
    eixo = plt.subplot(10, 10, i + 1 + imagens * 2)
    plt.imshow(imagens_decod[indice_imagem].reshape(28, 28))
    plt.title('Imagem Decodificada')
    plt.xticks(())
    plt.yticks(())
