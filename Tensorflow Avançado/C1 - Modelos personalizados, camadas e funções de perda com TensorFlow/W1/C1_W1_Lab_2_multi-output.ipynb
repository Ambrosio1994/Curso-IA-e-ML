# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %%
## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green',
             label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units=128, activation='relu')(input_layer)
second_dense = Dense(units=128, activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units=1, name='y1_output')(second_dense)
third_dense = Dense(units=64, activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units=1, name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2             │ (None, 8)              │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_3 (Dense)           │ (None, 128)            │          1,152 │ input_layer_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_4 (Dense)           │ (None, 128)            │         16,512 │ dense_3[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_5 (Dense)           │ (None, 64)             │          8,256 │ dense_4[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ y1_output (Dense)         │ (None, 1)              │            129 │ dense_4[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ y2_output (Dense)         │ (None, 1)              │             65 │ dense_5[0][0]          │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 26,114 (102.01 KB)
#  Trainable params: 26,114 (102.01 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(learning_rate=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Epoch 1/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 562.4575 - y1_output_root_mean_squared_error: 16.2684 - y2_output_root_mean_squared_error: 15.9477 - val_loss: 28.0400 - val_y1_output_root_mean_squared_error: 3.5015 - val_y2_output_root_mean_squared_error: 3.9724
# Epoch 2/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 32.7826 - y1_output_root_mean_squared_error: 3.5463 - y2_output_root_mean_squared_error: 4.4743 - val_loss: 40.0501 - val_y1_output_root_mean_squared_error: 3.9424 - val_y2_output_root_mean_squared_error: 4.9505
# Epoch 3/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 29.8941 - y1_output_root_mean_squared_error: 3.4092 - y2_output_root_mean_squared_error: 4.2611 - val_loss: 18.7106 - val_y1_output_root_mean_squared_error: 3.1621 - val_y2_output_root_mean_squared_error: 2.9515
# Epoch 4/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 27.2243 - y1_output_root_mean_squared_error: 3.1906 - y2_output_root_mean_squared_error: 4.1051 - val_loss: 13.9542 - val_y1_output_root_mean_squared_error: 2.6782 - val_y2_output_root_mean_squared_error: 2.6041
# Epoch 5/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 31.1193 - y1_output_root_mean_squared_error: 3.3298 - y2_output_root_mean_squared_error: 4.4633 - val_loss: 24.4153 - val_y1_output_root_mean_squared_error: 3.3127 - val_y2_output_root_mean_squared_error: 3.6663
# Epoch 6/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 36.8652 - y1_output_root_mean_squared_error: 3.4668 - y2_output_root_mean_squared_error: 4.9608 - val_loss: 34.5831 - val_y1_output_root_mean_squared_error: 3.0348 - val_y2_output_root_mean_squared_error: 5.0372
# Epoch 7/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 25.2123 - y1_output_root_mean_squared_error: 3.0223 - y2_output_root_mean_squared_error: 3.9690 - val_loss: 44.5800 - val_y1_output_root_mean_squared_error: 3.3676 - val_y2_output_root_mean_squared_error: 5.7654
# Epoch 8/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 24.3482 - y1_output_root_mean_squared_error: 2.9474 - y2_output_root_mean_squared_error: 3.9491 - val_loss: 65.4318 - val_y1_output_root_mean_squared_error: 4.3908 - val_y2_output_root_mean_squared_error: 6.7936
# Epoch 9/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 24.7700 - y1_output_root_mean_squared_error: 3.0093 - y2_output_root_mean_squared_error: 3.9489 - val_loss: 17.2314 - val_y1_output_root_mean_squared_error: 2.8177 - val_y2_output_root_mean_squared_error: 3.0483
# Epoch 10/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 19.9459 - y1_output_root_mean_squared_error: 2.8051 - y2_output_root_mean_squared_error: 3.4536 - val_loss: 48.5099 - val_y1_output_root_mean_squared_error: 3.1147 - val_y2_output_root_mean_squared_error: 6.2296
# Epoch 11/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 31.0772 - y1_output_root_mean_squared_error: 3.1472 - y2_output_root_mean_squared_error: 4.5366 - val_loss: 16.5001 - val_y1_output_root_mean_squared_error: 2.7541 - val_y2_output_root_mean_squared_error: 2.9858
# Epoch 12/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 19.2111 - y1_output_root_mean_squared_error: 2.8327 - y2_output_root_mean_squared_error: 3.3321 - val_loss: 12.0945 - val_y1_output_root_mean_squared_error: 2.4847 - val_y2_output_root_mean_squared_error: 2.4333
# Epoch 13/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 19.4756 - y1_output_root_mean_squared_error: 2.8062 - y2_output_root_mean_squared_error: 3.3997 - val_loss: 55.4438 - val_y1_output_root_mean_squared_error: 3.7213 - val_y2_output_root_mean_squared_error: 6.4495
# Epoch 14/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 27.1136 - y1_output_root_mean_squared_error: 3.0249 - y2_output_root_mean_squared_error: 4.1638 - val_loss: 58.9889 - val_y1_output_root_mean_squared_error: 3.4120 - val_y2_output_root_mean_squared_error: 6.8809
# Epoch 15/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 24.0187 - y1_output_root_mean_squared_error: 2.8153 - y2_output_root_mean_squared_error: 3.9706 - val_loss: 33.8681 - val_y1_output_root_mean_squared_error: 2.6620 - val_y2_output_root_mean_squared_error: 5.1751
# Epoch 16/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 19.6285 - y1_output_root_mean_squared_error: 2.7370 - y2_output_root_mean_squared_error: 3.4725 - val_loss: 12.9818 - val_y1_output_root_mean_squared_error: 2.3700 - val_y2_output_root_mean_squared_error: 2.7138
# Epoch 17/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 19.5195 - y1_output_root_mean_squared_error: 2.7814 - y2_output_root_mean_squared_error: 3.4161 - val_loss: 33.7760 - val_y1_output_root_mean_squared_error: 2.5272 - val_y2_output_root_mean_squared_error: 5.2335
# Epoch 18/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 19.7667 - y1_output_root_mean_squared_error: 2.7384 - y2_output_root_mean_squared_error: 3.4876 - val_loss: 12.4050 - val_y1_output_root_mean_squared_error: 2.3608 - val_y2_output_root_mean_squared_error: 2.6138
# Epoch 19/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 17.2691 - y1_output_root_mean_squared_error: 2.5547 - y2_output_root_mean_squared_error: 3.2750 - val_loss: 34.6437 - val_y1_output_root_mean_squared_error: 3.3630 - val_y2_output_root_mean_squared_error: 4.8305
# Epoch 20/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 23.4069 - y1_output_root_mean_squared_error: 2.6384 - y2_output_root_mean_squared_error: 3.9380 - val_loss: 12.6708 - val_y1_output_root_mean_squared_error: 2.2844 - val_y2_output_root_mean_squared_error: 2.7299
# Epoch 21/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 15.7814 - y1_output_root_mean_squared_error: 2.3552 - y2_output_root_mean_squared_error: 3.1903 - val_loss: 14.6924 - val_y1_output_root_mean_squared_error: 2.4486 - val_y2_output_root_mean_squared_error: 2.9490
# Epoch 22/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 15.8698 - y1_output_root_mean_squared_error: 2.4081 - y2_output_root_mean_squared_error: 3.1706 - val_loss: 11.0178 - val_y1_output_root_mean_squared_error: 2.1674 - val_y2_output_root_mean_squared_error: 2.5140
# Epoch 23/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 15.7604 - y1_output_root_mean_squared_error: 2.2710 - y2_output_root_mean_squared_error: 3.2398 - val_loss: 12.5672 - val_y1_output_root_mean_squared_error: 2.2134 - val_y2_output_root_mean_squared_error: 2.7691
# Epoch 24/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 17.6558 - y1_output_root_mean_squared_error: 2.4992 - y2_output_root_mean_squared_error: 3.3715 - val_loss: 23.1239 - val_y1_output_root_mean_squared_error: 2.6709 - val_y2_output_root_mean_squared_error: 3.9988
# Epoch 25/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 15.6248 - y1_output_root_mean_squared_error: 2.4316 - y2_output_root_mean_squared_error: 3.1010 - val_loss: 13.2040 - val_y1_output_root_mean_squared_error: 2.2636 - val_y2_output_root_mean_squared_error: 2.8425
# Epoch 26/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 13.5545 - y1_output_root_mean_squared_error: 2.1519 - y2_output_root_mean_squared_error: 2.9309 - val_loss: 13.8510 - val_y1_output_root_mean_squared_error: 2.4361 - val_y2_output_root_mean_squared_error: 2.8136
# Epoch 27/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 11.8383 - y1_output_root_mean_squared_error: 2.0829 - y2_output_root_mean_squared_error: 2.7122 - val_loss: 7.9608 - val_y1_output_root_mean_squared_error: 1.9636 - val_y2_output_root_mean_squared_error: 2.0261
# Epoch 28/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 13.2100 - y1_output_root_mean_squared_error: 2.1913 - y2_output_root_mean_squared_error: 2.8897 - val_loss: 8.0088 - val_y1_output_root_mean_squared_error: 1.8597 - val_y2_output_root_mean_squared_error: 2.1331
# Epoch 29/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 13.1312 - y1_output_root_mean_squared_error: 2.1571 - y2_output_root_mean_squared_error: 2.9024 - val_loss: 9.0011 - val_y1_output_root_mean_squared_error: 1.8963 - val_y2_output_root_mean_squared_error: 2.3249
# Epoch 30/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 12.1561 - y1_output_root_mean_squared_error: 1.9440 - y2_output_root_mean_squared_error: 2.8771 - val_loss: 8.4947 - val_y1_output_root_mean_squared_error: 1.8109 - val_y2_output_root_mean_squared_error: 2.2837
# Epoch 31/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.8845 - y1_output_root_mean_squared_error: 1.8821 - y2_output_root_mean_squared_error: 2.4967 - val_loss: 12.7442 - val_y1_output_root_mean_squared_error: 1.9947 - val_y2_output_root_mean_squared_error: 2.9606
# Epoch 32/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.9547 - y1_output_root_mean_squared_error: 1.9117 - y2_output_root_mean_squared_error: 2.4702 - val_loss: 7.1780 - val_y1_output_root_mean_squared_error: 1.6604 - val_y2_output_root_mean_squared_error: 2.1026
# Epoch 33/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.4830 - y1_output_root_mean_squared_error: 1.7010 - y2_output_root_mean_squared_error: 2.3568 - val_loss: 8.4363 - val_y1_output_root_mean_squared_error: 1.8866 - val_y2_output_root_mean_squared_error: 2.2084
# Epoch 34/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.3453 - y1_output_root_mean_squared_error: 1.7558 - y2_output_root_mean_squared_error: 2.2898 - val_loss: 8.6195 - val_y1_output_root_mean_squared_error: 2.0006 - val_y2_output_root_mean_squared_error: 2.1487
# Epoch 35/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.4616 - y1_output_root_mean_squared_error: 1.6703 - y2_output_root_mean_squared_error: 2.3640 - val_loss: 11.6421 - val_y1_output_root_mean_squared_error: 1.9109 - val_y2_output_root_mean_squared_error: 2.8268
# Epoch 36/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.7207 - y1_output_root_mean_squared_error: 1.6125 - y2_output_root_mean_squared_error: 2.2397 - val_loss: 11.1249 - val_y1_output_root_mean_squared_error: 2.1275 - val_y2_output_root_mean_squared_error: 2.5688
# Epoch 37/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.6161 - y1_output_root_mean_squared_error: 1.6503 - y2_output_root_mean_squared_error: 2.4136 - val_loss: 10.6990 - val_y1_output_root_mean_squared_error: 1.7300 - val_y2_output_root_mean_squared_error: 2.7760
# Epoch 38/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 12.0739 - y1_output_root_mean_squared_error: 1.9727 - y2_output_root_mean_squared_error: 2.8336 - val_loss: 6.4341 - val_y1_output_root_mean_squared_error: 1.6286 - val_y2_output_root_mean_squared_error: 1.9447
# Epoch 39/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.6933 - y1_output_root_mean_squared_error: 1.5428 - y2_output_root_mean_squared_error: 2.3000 - val_loss: 7.0671 - val_y1_output_root_mean_squared_error: 1.7892 - val_y2_output_root_mean_squared_error: 1.9661
# Epoch 40/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.5196 - y1_output_root_mean_squared_error: 1.5258 - y2_output_root_mean_squared_error: 2.2703 - val_loss: 10.4214 - val_y1_output_root_mean_squared_error: 1.8517 - val_y2_output_root_mean_squared_error: 2.6444
# Epoch 41/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.9157 - y1_output_root_mean_squared_error: 1.6080 - y2_output_root_mean_squared_error: 2.2856 - val_loss: 16.7917 - val_y1_output_root_mean_squared_error: 2.2290 - val_y2_output_root_mean_squared_error: 3.4385
# Epoch 42/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.7317 - y1_output_root_mean_squared_error: 1.6554 - y2_output_root_mean_squared_error: 2.4381 - val_loss: 11.8689 - val_y1_output_root_mean_squared_error: 1.7739 - val_y2_output_root_mean_squared_error: 2.9533
# Epoch 43/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.9847 - y1_output_root_mean_squared_error: 1.5475 - y2_output_root_mean_squared_error: 2.3538 - val_loss: 6.7711 - val_y1_output_root_mean_squared_error: 1.6304 - val_y2_output_root_mean_squared_error: 2.0280
# Epoch 44/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.4522 - y1_output_root_mean_squared_error: 1.4816 - y2_output_root_mean_squared_error: 2.0503 - val_loss: 6.5247 - val_y1_output_root_mean_squared_error: 1.4357 - val_y2_output_root_mean_squared_error: 2.1127
# Epoch 45/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.3298 - y1_output_root_mean_squared_error: 1.4680 - y2_output_root_mean_squared_error: 2.0377 - val_loss: 8.1395 - val_y1_output_root_mean_squared_error: 1.4354 - val_y2_output_root_mean_squared_error: 2.4656
# Epoch 46/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.4354 - y1_output_root_mean_squared_error: 1.5602 - y2_output_root_mean_squared_error: 2.2209 - val_loss: 7.9445 - val_y1_output_root_mean_squared_error: 1.6631 - val_y2_output_root_mean_squared_error: 2.2757
# Epoch 47/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.3724 - y1_output_root_mean_squared_error: 1.5200 - y2_output_root_mean_squared_error: 2.4503 - val_loss: 10.7203 - val_y1_output_root_mean_squared_error: 1.7647 - val_y2_output_root_mean_squared_error: 2.7579
# Epoch 48/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 10.7300 - y1_output_root_mean_squared_error: 1.8031 - y2_output_root_mean_squared_error: 2.6999 - val_loss: 9.1888 - val_y1_output_root_mean_squared_error: 1.7738 - val_y2_output_root_mean_squared_error: 2.4581
# Epoch 49/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.8601 - y1_output_root_mean_squared_error: 1.4366 - y2_output_root_mean_squared_error: 2.1861 - val_loss: 15.3819 - val_y1_output_root_mean_squared_error: 1.8953 - val_y2_output_root_mean_squared_error: 3.4336
# Epoch 50/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.7046 - y1_output_root_mean_squared_error: 1.4530 - y2_output_root_mean_squared_error: 2.5343 - val_loss: 21.8832 - val_y1_output_root_mean_squared_error: 2.4647 - val_y2_output_root_mean_squared_error: 3.9760
# Epoch 51/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.5931 - y1_output_root_mean_squared_error: 1.5592 - y2_output_root_mean_squared_error: 2.4468 - val_loss: 13.9268 - val_y1_output_root_mean_squared_error: 1.7447 - val_y2_output_root_mean_squared_error: 3.2989
# Epoch 52/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.3394 - y1_output_root_mean_squared_error: 1.5133 - y2_output_root_mean_squared_error: 2.2359 - val_loss: 12.7347 - val_y1_output_root_mean_squared_error: 2.4044 - val_y2_output_root_mean_squared_error: 2.6369
# Epoch 53/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.1513 - y1_output_root_mean_squared_error: 1.6324 - y2_output_root_mean_squared_error: 2.5086 - val_loss: 28.4435 - val_y1_output_root_mean_squared_error: 2.8144 - val_y2_output_root_mean_squared_error: 4.5302
# Epoch 54/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 10.0582 - y1_output_root_mean_squared_error: 1.5685 - y2_output_root_mean_squared_error: 2.7456 - val_loss: 18.4369 - val_y1_output_root_mean_squared_error: 2.5687 - val_y2_output_root_mean_squared_error: 3.4407
# Epoch 55/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 10.3031 - y1_output_root_mean_squared_error: 1.6880 - y2_output_root_mean_squared_error: 2.6425 - val_loss: 5.6830 - val_y1_output_root_mean_squared_error: 1.4563 - val_y2_output_root_mean_squared_error: 1.8873
# Epoch 56/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.8715 - y1_output_root_mean_squared_error: 1.2912 - y2_output_root_mean_squared_error: 2.0408 - val_loss: 5.1900 - val_y1_output_root_mean_squared_error: 1.2207 - val_y2_output_root_mean_squared_error: 1.9235
# Epoch 57/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.0997 - y1_output_root_mean_squared_error: 1.4187 - y2_output_root_mean_squared_error: 2.0176 - val_loss: 9.7849 - val_y1_output_root_mean_squared_error: 1.5807 - val_y2_output_root_mean_squared_error: 2.6993
# Epoch 58/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.8066 - y1_output_root_mean_squared_error: 1.2858 - y2_output_root_mean_squared_error: 2.0312 - val_loss: 6.6494 - val_y1_output_root_mean_squared_error: 1.1963 - val_y2_output_root_mean_squared_error: 2.2843
# Epoch 59/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.4687 - y1_output_root_mean_squared_error: 1.2422 - y2_output_root_mean_squared_error: 1.9638 - val_loss: 5.4053 - val_y1_output_root_mean_squared_error: 1.1212 - val_y2_output_root_mean_squared_error: 2.0367
# Epoch 60/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.5549 - y1_output_root_mean_squared_error: 1.3061 - y2_output_root_mean_squared_error: 2.1937 - val_loss: 5.9815 - val_y1_output_root_mean_squared_error: 1.4719 - val_y2_output_root_mean_squared_error: 1.9532
# Epoch 61/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.8279 - y1_output_root_mean_squared_error: 1.4027 - y2_output_root_mean_squared_error: 2.1855 - val_loss: 13.5576 - val_y1_output_root_mean_squared_error: 1.3553 - val_y2_output_root_mean_squared_error: 3.4236
# Epoch 62/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 5.9933 - y1_output_root_mean_squared_error: 1.3656 - y2_output_root_mean_squared_error: 2.0113 - val_loss: 17.7325 - val_y1_output_root_mean_squared_error: 1.3479 - val_y2_output_root_mean_squared_error: 3.9894
# Epoch 63/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.6818 - y1_output_root_mean_squared_error: 1.2103 - y2_output_root_mean_squared_error: 2.0308 - val_loss: 6.8745 - val_y1_output_root_mean_squared_error: 1.6375 - val_y2_output_root_mean_squared_error: 2.0477
# Epoch 64/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.6343 - y1_output_root_mean_squared_error: 1.3182 - y2_output_root_mean_squared_error: 1.9676 - val_loss: 3.8070 - val_y1_output_root_mean_squared_error: 1.1135 - val_y2_output_root_mean_squared_error: 1.6022
# Epoch 65/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.2871 - y1_output_root_mean_squared_error: 1.0852 - y2_output_root_mean_squared_error: 1.7610 - val_loss: 3.1644 - val_y1_output_root_mean_squared_error: 0.9834 - val_y2_output_root_mean_squared_error: 1.4823
# Epoch 66/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6163 - y1_output_root_mean_squared_error: 1.0793 - y2_output_root_mean_squared_error: 1.8499 - val_loss: 9.5625 - val_y1_output_root_mean_squared_error: 2.0475 - val_y2_output_root_mean_squared_error: 2.3174
# Epoch 67/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.5359 - y1_output_root_mean_squared_error: 1.1830 - y2_output_root_mean_squared_error: 2.0230 - val_loss: 13.9168 - val_y1_output_root_mean_squared_error: 1.3183 - val_y2_output_root_mean_squared_error: 3.4898
# Epoch 68/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3656 - y1_output_root_mean_squared_error: 1.0570 - y2_output_root_mean_squared_error: 2.0373 - val_loss: 3.5971 - val_y1_output_root_mean_squared_error: 1.0902 - val_y2_output_root_mean_squared_error: 1.5519
# Epoch 69/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0764 - y1_output_root_mean_squared_error: 0.9654 - y2_output_root_mean_squared_error: 1.7669 - val_loss: 7.3219 - val_y1_output_root_mean_squared_error: 1.0764 - val_y2_output_root_mean_squared_error: 2.4826
# Epoch 70/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.5404 - y1_output_root_mean_squared_error: 1.4671 - y2_output_root_mean_squared_error: 2.4506 - val_loss: 4.0018 - val_y1_output_root_mean_squared_error: 1.1579 - val_y2_output_root_mean_squared_error: 1.6312
# Epoch 71/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7012 - y1_output_root_mean_squared_error: 1.0207 - y2_output_root_mean_squared_error: 1.6203 - val_loss: 3.2558 - val_y1_output_root_mean_squared_error: 0.9261 - val_y2_output_root_mean_squared_error: 1.5486
# Epoch 72/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6578 - y1_output_root_mean_squared_error: 0.9944 - y2_output_root_mean_squared_error: 1.6313 - val_loss: 3.0452 - val_y1_output_root_mean_squared_error: 0.9086 - val_y2_output_root_mean_squared_error: 1.4899
# Epoch 73/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4845 - y1_output_root_mean_squared_error: 0.9475 - y2_output_root_mean_squared_error: 1.8826 - val_loss: 6.1573 - val_y1_output_root_mean_squared_error: 1.5693 - val_y2_output_root_mean_squared_error: 1.9221
# Epoch 74/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.7011 - y1_output_root_mean_squared_error: 1.5919 - y2_output_root_mean_squared_error: 2.4125 - val_loss: 3.6261 - val_y1_output_root_mean_squared_error: 1.0060 - val_y2_output_root_mean_squared_error: 1.6168
# Epoch 75/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4648 - y1_output_root_mean_squared_error: 1.0372 - y2_output_root_mean_squared_error: 1.5411 - val_loss: 5.0008 - val_y1_output_root_mean_squared_error: 0.7900 - val_y2_output_root_mean_squared_error: 2.0921
# Epoch 76/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3791 - y1_output_root_mean_squared_error: 0.9264 - y2_output_root_mean_squared_error: 1.5849 - val_loss: 3.5240 - val_y1_output_root_mean_squared_error: 0.6928 - val_y2_output_root_mean_squared_error: 1.7447
# Epoch 77/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7573 - y1_output_root_mean_squared_error: 0.9472 - y2_output_root_mean_squared_error: 1.6825 - val_loss: 4.4329 - val_y1_output_root_mean_squared_error: 1.0777 - val_y2_output_root_mean_squared_error: 1.8087
# Epoch 78/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8166 - y1_output_root_mean_squared_error: 1.2777 - y2_output_root_mean_squared_error: 1.7671 - val_loss: 3.9927 - val_y1_output_root_mean_squared_error: 0.7743 - val_y2_output_root_mean_squared_error: 1.8420
# Epoch 79/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0671 - y1_output_root_mean_squared_error: 0.8610 - y2_output_root_mean_squared_error: 1.5212 - val_loss: 3.1070 - val_y1_output_root_mean_squared_error: 0.8971 - val_y2_output_root_mean_squared_error: 1.5173
# Epoch 80/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3018 - y1_output_root_mean_squared_error: 0.8380 - y2_output_root_mean_squared_error: 1.6058 - val_loss: 4.1263 - val_y1_output_root_mean_squared_error: 0.9029 - val_y2_output_root_mean_squared_error: 1.8196
# Epoch 81/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0867 - y1_output_root_mean_squared_error: 1.0056 - y2_output_root_mean_squared_error: 1.7446 - val_loss: 3.0237 - val_y1_output_root_mean_squared_error: 0.9323 - val_y2_output_root_mean_squared_error: 1.4679
# Epoch 82/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8616 - y1_output_root_mean_squared_error: 0.7862 - y2_output_root_mean_squared_error: 1.4919 - val_loss: 5.3779 - val_y1_output_root_mean_squared_error: 0.8248 - val_y2_output_root_mean_squared_error: 2.1674
# Epoch 83/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7808 - y1_output_root_mean_squared_error: 0.8837 - y2_output_root_mean_squared_error: 1.4096 - val_loss: 2.1623 - val_y1_output_root_mean_squared_error: 0.7104 - val_y2_output_root_mean_squared_error: 1.2875
# Epoch 84/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3404 - y1_output_root_mean_squared_error: 0.9762 - y2_output_root_mean_squared_error: 1.5199 - val_loss: 3.0324 - val_y1_output_root_mean_squared_error: 0.9143 - val_y2_output_root_mean_squared_error: 1.4820
# Epoch 85/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9539 - y1_output_root_mean_squared_error: 0.8107 - y2_output_root_mean_squared_error: 1.5103 - val_loss: 6.2673 - val_y1_output_root_mean_squared_error: 0.8334 - val_y2_output_root_mean_squared_error: 2.3607
# Epoch 86/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0791 - y1_output_root_mean_squared_error: 0.8153 - y2_output_root_mean_squared_error: 1.5351 - val_loss: 3.9627 - val_y1_output_root_mean_squared_error: 1.1239 - val_y2_output_root_mean_squared_error: 1.6430
# Epoch 87/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7081 - y1_output_root_mean_squared_error: 0.9296 - y2_output_root_mean_squared_error: 1.3532 - val_loss: 2.1999 - val_y1_output_root_mean_squared_error: 0.7400 - val_y2_output_root_mean_squared_error: 1.2854
# Epoch 88/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.4591 - y1_output_root_mean_squared_error: 0.7138 - y2_output_root_mean_squared_error: 1.3924 - val_loss: 19.5677 - val_y1_output_root_mean_squared_error: 2.3306 - val_y2_output_root_mean_squared_error: 3.7598
# Epoch 89/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5556 - y1_output_root_mean_squared_error: 1.0050 - y2_output_root_mean_squared_error: 1.5677 - val_loss: 5.9523 - val_y1_output_root_mean_squared_error: 1.3773 - val_y2_output_root_mean_squared_error: 2.0138
# Epoch 90/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5466 - y1_output_root_mean_squared_error: 1.1103 - y2_output_root_mean_squared_error: 1.8101 - val_loss: 16.4568 - val_y1_output_root_mean_squared_error: 2.6039 - val_y2_output_root_mean_squared_error: 3.1107
# Epoch 91/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 12.2917 - y1_output_root_mean_squared_error: 1.7721 - y2_output_root_mean_squared_error: 2.8862 - val_loss: 4.2802 - val_y1_output_root_mean_squared_error: 0.8429 - val_y2_output_root_mean_squared_error: 1.8894
# Epoch 92/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.4530 - y1_output_root_mean_squared_error: 0.7691 - y2_output_root_mean_squared_error: 1.3625 - val_loss: 3.0471 - val_y1_output_root_mean_squared_error: 0.7068 - val_y2_output_root_mean_squared_error: 1.5961
# Epoch 93/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.9820 - y1_output_root_mean_squared_error: 1.5940 - y2_output_root_mean_squared_error: 2.4026 - val_loss: 2.5726 - val_y1_output_root_mean_squared_error: 0.8579 - val_y2_output_root_mean_squared_error: 1.3552
# Epoch 94/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8190 - y1_output_root_mean_squared_error: 0.8186 - y2_output_root_mean_squared_error: 1.4605 - val_loss: 2.4670 - val_y1_output_root_mean_squared_error: 0.8362 - val_y2_output_root_mean_squared_error: 1.3296
# Epoch 95/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5853 - y1_output_root_mean_squared_error: 0.7600 - y2_output_root_mean_squared_error: 1.4123 - val_loss: 10.3477 - val_y1_output_root_mean_squared_error: 1.0570 - val_y2_output_root_mean_squared_error: 3.0382
# Epoch 96/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0697 - y1_output_root_mean_squared_error: 0.8560 - y2_output_root_mean_squared_error: 1.5059 - val_loss: 4.2602 - val_y1_output_root_mean_squared_error: 0.5822 - val_y2_output_root_mean_squared_error: 1.9802
# Epoch 97/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9777 - y1_output_root_mean_squared_error: 0.8237 - y2_output_root_mean_squared_error: 1.5066 - val_loss: 7.3492 - val_y1_output_root_mean_squared_error: 1.4826 - val_y2_output_root_mean_squared_error: 2.2696
# Epoch 98/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7063 - y1_output_root_mean_squared_error: 0.7876 - y2_output_root_mean_squared_error: 1.4392 - val_loss: 3.7165 - val_y1_output_root_mean_squared_error: 0.7904 - val_y2_output_root_mean_squared_error: 1.7583
# Epoch 99/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.2325 - y1_output_root_mean_squared_error: 0.7507 - y2_output_root_mean_squared_error: 1.2807 - val_loss: 4.9027 - val_y1_output_root_mean_squared_error: 1.1369 - val_y2_output_root_mean_squared_error: 1.9000
# Epoch 100/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0010 - y1_output_root_mean_squared_error: 0.9808 - y2_output_root_mean_squared_error: 1.7340 - val_loss: 2.5933 - val_y1_output_root_mean_squared_error: 0.6714 - val_y2_output_root_mean_squared_error: 1.4638
# Epoch 101/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.8132 - y1_output_root_mean_squared_error: 0.7963 - y2_output_root_mean_squared_error: 1.4724 - val_loss: 28.1929 - val_y1_output_root_mean_squared_error: 3.0248 - val_y2_output_root_mean_squared_error: 4.3639
# Epoch 102/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 8.6020 - y1_output_root_mean_squared_error: 1.3726 - y2_output_root_mean_squared_error: 2.4706 - val_loss: 3.2143 - val_y1_output_root_mean_squared_error: 0.9929 - val_y2_output_root_mean_squared_error: 1.4928
# Epoch 103/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2.9168 - y1_output_root_mean_squared_error: 0.7847 - y2_output_root_mean_squared_error: 1.5112 - val_loss: 2.4672 - val_y1_output_root_mean_squared_error: 0.8455 - val_y2_output_root_mean_squared_error: 1.3237
# Epoch 104/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.3354 - y1_output_root_mean_squared_error: 0.7371 - y2_output_root_mean_squared_error: 1.3299 - val_loss: 3.0465 - val_y1_output_root_mean_squared_error: 0.7580 - val_y2_output_root_mean_squared_error: 1.5723
# Epoch 105/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8271 - y1_output_root_mean_squared_error: 0.8418 - y2_output_root_mean_squared_error: 1.4516 - val_loss: 1.9272 - val_y1_output_root_mean_squared_error: 0.6022 - val_y2_output_root_mean_squared_error: 1.2508
# Epoch 106/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.0278 - y1_output_root_mean_squared_error: 0.6801 - y2_output_root_mean_squared_error: 1.2483 - val_loss: 3.4731 - val_y1_output_root_mean_squared_error: 0.6473 - val_y2_output_root_mean_squared_error: 1.7476
# Epoch 107/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9496 - y1_output_root_mean_squared_error: 0.6986 - y2_output_root_mean_squared_error: 1.2054 - val_loss: 2.2651 - val_y1_output_root_mean_squared_error: 0.7479 - val_y2_output_root_mean_squared_error: 1.3061
# Epoch 108/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.4602 - y1_output_root_mean_squared_error: 0.7796 - y2_output_root_mean_squared_error: 1.3561 - val_loss: 5.0622 - val_y1_output_root_mean_squared_error: 1.0871 - val_y2_output_root_mean_squared_error: 1.9699
# Epoch 109/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.4455 - y1_output_root_mean_squared_error: 0.7041 - y2_output_root_mean_squared_error: 1.3881 - val_loss: 2.0725 - val_y1_output_root_mean_squared_error: 0.8062 - val_y2_output_root_mean_squared_error: 1.1927
# Epoch 110/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9249 - y1_output_root_mean_squared_error: 0.7713 - y2_output_root_mean_squared_error: 1.1443 - val_loss: 320.2741 - val_y1_output_root_mean_squared_error: 10.5384 - val_y2_output_root_mean_squared_error: 14.4643
# Epoch 111/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 17.5512 - y1_output_root_mean_squared_error: 2.3353 - y2_output_root_mean_squared_error: 3.1188 - val_loss: 2.4360 - val_y1_output_root_mean_squared_error: 0.6458 - val_y2_output_root_mean_squared_error: 1.4209
# Epoch 112/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6080 - y1_output_root_mean_squared_error: 0.9558 - y2_output_root_mean_squared_error: 1.6187 - val_loss: 1.8482 - val_y1_output_root_mean_squared_error: 0.7093 - val_y2_output_root_mean_squared_error: 1.1598
# Epoch 113/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.1378 - y1_output_root_mean_squared_error: 0.6628 - y2_output_root_mean_squared_error: 1.2953 - val_loss: 3.6597 - val_y1_output_root_mean_squared_error: 1.0441 - val_y2_output_root_mean_squared_error: 1.6030
# Epoch 114/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.3326 - y1_output_root_mean_squared_error: 0.6736 - y2_output_root_mean_squared_error: 1.3624 - val_loss: 1.7026 - val_y1_output_root_mean_squared_error: 0.5792 - val_y2_output_root_mean_squared_error: 1.1693
# Epoch 115/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6054 - y1_output_root_mean_squared_error: 0.6826 - y2_output_root_mean_squared_error: 1.4568 - val_loss: 2.6798 - val_y1_output_root_mean_squared_error: 0.7455 - val_y2_output_root_mean_squared_error: 1.4574
# Epoch 116/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.8665 - y1_output_root_mean_squared_error: 0.7047 - y2_output_root_mean_squared_error: 1.1651 - val_loss: 1.6365 - val_y1_output_root_mean_squared_error: 0.5752 - val_y2_output_root_mean_squared_error: 1.1426
# Epoch 117/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.0983 - y1_output_root_mean_squared_error: 0.6991 - y2_output_root_mean_squared_error: 1.2636 - val_loss: 2.6683 - val_y1_output_root_mean_squared_error: 1.0006 - val_y2_output_root_mean_squared_error: 1.2911
# Epoch 118/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1009 - y1_output_root_mean_squared_error: 0.8552 - y2_output_root_mean_squared_error: 1.5261 - val_loss: 2.9376 - val_y1_output_root_mean_squared_error: 0.6649 - val_y2_output_root_mean_squared_error: 1.5797
# Epoch 119/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.3606 - y1_output_root_mean_squared_error: 0.6903 - y2_output_root_mean_squared_error: 1.3570 - val_loss: 2.2342 - val_y1_output_root_mean_squared_error: 0.5526 - val_y2_output_root_mean_squared_error: 1.3888
# Epoch 120/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.4631 - y1_output_root_mean_squared_error: 0.7345 - y2_output_root_mean_squared_error: 1.3680 - val_loss: 2.2549 - val_y1_output_root_mean_squared_error: 0.6149 - val_y2_output_root_mean_squared_error: 1.3700
# Epoch 121/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2444 - y1_output_root_mean_squared_error: 0.7214 - y2_output_root_mean_squared_error: 1.3029 - val_loss: 2.5307 - val_y1_output_root_mean_squared_error: 0.9649 - val_y2_output_root_mean_squared_error: 1.2648
# Epoch 122/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9804 - y1_output_root_mean_squared_error: 0.7103 - y2_output_root_mean_squared_error: 1.2061 - val_loss: 2.0523 - val_y1_output_root_mean_squared_error: 0.7022 - val_y2_output_root_mean_squared_error: 1.2487
# Epoch 123/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7546 - y1_output_root_mean_squared_error: 0.6584 - y2_output_root_mean_squared_error: 1.1446 - val_loss: 2.9715 - val_y1_output_root_mean_squared_error: 1.0808 - val_y2_output_root_mean_squared_error: 1.3429
# Epoch 124/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6341 - y1_output_root_mean_squared_error: 0.8649 - y2_output_root_mean_squared_error: 1.3691 - val_loss: 1.8718 - val_y1_output_root_mean_squared_error: 0.7333 - val_y2_output_root_mean_squared_error: 1.1550
# Epoch 125/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6314 - y1_output_root_mean_squared_error: 0.9210 - y2_output_root_mean_squared_error: 1.6563 - val_loss: 2.9744 - val_y1_output_root_mean_squared_error: 0.7450 - val_y2_output_root_mean_squared_error: 1.5554
# Epoch 126/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9097 - y1_output_root_mean_squared_error: 0.6775 - y2_output_root_mean_squared_error: 1.1983 - val_loss: 17.9362 - val_y1_output_root_mean_squared_error: 1.8441 - val_y2_output_root_mean_squared_error: 3.8125
# Epoch 127/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0325 - y1_output_root_mean_squared_error: 0.9184 - y2_output_root_mean_squared_error: 1.7097 - val_loss: 2.0927 - val_y1_output_root_mean_squared_error: 0.5686 - val_y2_output_root_mean_squared_error: 1.3302
# Epoch 128/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.3179 - y1_output_root_mean_squared_error: 0.7103 - y2_output_root_mean_squared_error: 1.3386 - val_loss: 1.9631 - val_y1_output_root_mean_squared_error: 0.5900 - val_y2_output_root_mean_squared_error: 1.2708
# Epoch 129/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.4995 - y1_output_root_mean_squared_error: 0.7289 - y2_output_root_mean_squared_error: 1.3604 - val_loss: 1.6872 - val_y1_output_root_mean_squared_error: 0.6893 - val_y2_output_root_mean_squared_error: 1.1009
# Epoch 130/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7011 - y1_output_root_mean_squared_error: 0.6259 - y2_output_root_mean_squared_error: 1.1356 - val_loss: 1.8801 - val_y1_output_root_mean_squared_error: 0.6146 - val_y2_output_root_mean_squared_error: 1.2257
# Epoch 131/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9790 - y1_output_root_mean_squared_error: 0.7086 - y2_output_root_mean_squared_error: 1.1988 - val_loss: 7.4897 - val_y1_output_root_mean_squared_error: 0.8147 - val_y2_output_root_mean_squared_error: 2.6127
# Epoch 132/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9912 - y1_output_root_mean_squared_error: 0.9693 - y2_output_root_mean_squared_error: 1.6970 - val_loss: 1.7250 - val_y1_output_root_mean_squared_error: 0.6642 - val_y2_output_root_mean_squared_error: 1.1331
# Epoch 133/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3562 - y1_output_root_mean_squared_error: 0.5573 - y2_output_root_mean_squared_error: 1.0180 - val_loss: 1.6746 - val_y1_output_root_mean_squared_error: 0.6923 - val_y2_output_root_mean_squared_error: 1.0933
# Epoch 134/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3706 - y1_output_root_mean_squared_error: 0.6042 - y2_output_root_mean_squared_error: 0.9999 - val_loss: 1.7529 - val_y1_output_root_mean_squared_error: 0.7188 - val_y2_output_root_mean_squared_error: 1.1118
# Epoch 135/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6133 - y1_output_root_mean_squared_error: 0.5926 - y2_output_root_mean_squared_error: 1.1211 - val_loss: 1.9131 - val_y1_output_root_mean_squared_error: 0.8091 - val_y2_output_root_mean_squared_error: 1.1218
# Epoch 136/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9304 - y1_output_root_mean_squared_error: 0.6445 - y2_output_root_mean_squared_error: 1.2269 - val_loss: 1.8355 - val_y1_output_root_mean_squared_error: 0.6525 - val_y2_output_root_mean_squared_error: 1.1873
# Epoch 137/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2120 - y1_output_root_mean_squared_error: 0.5587 - y2_output_root_mean_squared_error: 0.9394 - val_loss: 3.2023 - val_y1_output_root_mean_squared_error: 0.8381 - val_y2_output_root_mean_squared_error: 1.5811
# Epoch 138/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1377 - y1_output_root_mean_squared_error: 0.6657 - y2_output_root_mean_squared_error: 1.2812 - val_loss: 1.9442 - val_y1_output_root_mean_squared_error: 0.7404 - val_y2_output_root_mean_squared_error: 1.1815
# Epoch 139/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4814 - y1_output_root_mean_squared_error: 0.5746 - y2_output_root_mean_squared_error: 1.0654 - val_loss: 5.6197 - val_y1_output_root_mean_squared_error: 1.0082 - val_y2_output_root_mean_squared_error: 2.1455
# Epoch 140/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.1197 - y1_output_root_mean_squared_error: 0.7293 - y2_output_root_mean_squared_error: 1.2536 - val_loss: 1.8640 - val_y1_output_root_mean_squared_error: 0.6886 - val_y2_output_root_mean_squared_error: 1.1789
# Epoch 141/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3735 - y1_output_root_mean_squared_error: 0.5911 - y2_output_root_mean_squared_error: 1.0088 - val_loss: 1.9258 - val_y1_output_root_mean_squared_error: 0.6656 - val_y2_output_root_mean_squared_error: 1.2177
# Epoch 142/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4279 - y1_output_root_mean_squared_error: 0.5717 - y2_output_root_mean_squared_error: 1.0478 - val_loss: 1.4769 - val_y1_output_root_mean_squared_error: 0.5819 - val_y2_output_root_mean_squared_error: 1.0669
# Epoch 143/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5801 - y1_output_root_mean_squared_error: 0.6156 - y2_output_root_mean_squared_error: 1.0905 - val_loss: 1.5912 - val_y1_output_root_mean_squared_error: 0.6542 - val_y2_output_root_mean_squared_error: 1.0785
# Epoch 144/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9203 - y1_output_root_mean_squared_error: 0.6261 - y2_output_root_mean_squared_error: 1.2281 - val_loss: 1.7635 - val_y1_output_root_mean_squared_error: 0.5208 - val_y2_output_root_mean_squared_error: 1.2216
# Epoch 145/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3302 - y1_output_root_mean_squared_error: 0.5348 - y2_output_root_mean_squared_error: 1.0103 - val_loss: 4.0612 - val_y1_output_root_mean_squared_error: 0.9721 - val_y2_output_root_mean_squared_error: 1.7653
# Epoch 146/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6186 - y1_output_root_mean_squared_error: 0.8261 - y2_output_root_mean_squared_error: 1.3847 - val_loss: 1.4029 - val_y1_output_root_mean_squared_error: 0.5600 - val_y2_output_root_mean_squared_error: 1.0437
# Epoch 147/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7728 - y1_output_root_mean_squared_error: 0.6194 - y2_output_root_mean_squared_error: 1.1752 - val_loss: 2.1173 - val_y1_output_root_mean_squared_error: 0.6988 - val_y2_output_root_mean_squared_error: 1.2763
# Epoch 148/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2.1806 - y1_output_root_mean_squared_error: 0.6858 - y2_output_root_mean_squared_error: 1.2992 - val_loss: 1.7321 - val_y1_output_root_mean_squared_error: 0.6359 - val_y2_output_root_mean_squared_error: 1.1523
# Epoch 149/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5991 - y1_output_root_mean_squared_error: 0.5690 - y2_output_root_mean_squared_error: 1.1248 - val_loss: 4.3377 - val_y1_output_root_mean_squared_error: 0.9654 - val_y2_output_root_mean_squared_error: 1.8455
# Epoch 150/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6741 - y1_output_root_mean_squared_error: 0.7023 - y2_output_root_mean_squared_error: 1.0750 - val_loss: 1.5241 - val_y1_output_root_mean_squared_error: 0.6406 - val_y2_output_root_mean_squared_error: 1.0554
# Epoch 151/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5025 - y1_output_root_mean_squared_error: 0.6033 - y2_output_root_mean_squared_error: 1.0635 - val_loss: 5.8838 - val_y1_output_root_mean_squared_error: 1.2322 - val_y2_output_root_mean_squared_error: 2.0894
# Epoch 152/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.3786 - y1_output_root_mean_squared_error: 0.7712 - y2_output_root_mean_squared_error: 1.3213 - val_loss: 3.0869 - val_y1_output_root_mean_squared_error: 0.7288 - val_y2_output_root_mean_squared_error: 1.5987
# Epoch 153/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6419 - y1_output_root_mean_squared_error: 0.5808 - y2_output_root_mean_squared_error: 1.1396 - val_loss: 2.0734 - val_y1_output_root_mean_squared_error: 0.5148 - val_y2_output_root_mean_squared_error: 1.3448
# Epoch 154/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5044 - y1_output_root_mean_squared_error: 0.5382 - y2_output_root_mean_squared_error: 1.0927 - val_loss: 2.2316 - val_y1_output_root_mean_squared_error: 0.7444 - val_y2_output_root_mean_squared_error: 1.2952
# Epoch 155/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5618 - y1_output_root_mean_squared_error: 0.6131 - y2_output_root_mean_squared_error: 1.0796 - val_loss: 3.2470 - val_y1_output_root_mean_squared_error: 0.6405 - val_y2_output_root_mean_squared_error: 1.6843
# Epoch 156/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.0057 - y1_output_root_mean_squared_error: 0.7392 - y2_output_root_mean_squared_error: 1.1945 - val_loss: 2.3479 - val_y1_output_root_mean_squared_error: 0.7172 - val_y2_output_root_mean_squared_error: 1.3540
# Epoch 157/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3637 - y1_output_root_mean_squared_error: 0.5922 - y2_output_root_mean_squared_error: 0.9997 - val_loss: 1.7704 - val_y1_output_root_mean_squared_error: 0.6492 - val_y2_output_root_mean_squared_error: 1.1615
# Epoch 158/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4459 - y1_output_root_mean_squared_error: 0.5707 - y2_output_root_mean_squared_error: 1.0549 - val_loss: 1.1584 - val_y1_output_root_mean_squared_error: 0.4880 - val_y2_output_root_mean_squared_error: 0.9593
# Epoch 159/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6331 - y1_output_root_mean_squared_error: 0.5497 - y2_output_root_mean_squared_error: 1.1487 - val_loss: 1.5933 - val_y1_output_root_mean_squared_error: 0.6109 - val_y2_output_root_mean_squared_error: 1.1046
# Epoch 160/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4668 - y1_output_root_mean_squared_error: 0.5538 - y2_output_root_mean_squared_error: 1.0719 - val_loss: 1.8687 - val_y1_output_root_mean_squared_error: 0.7449 - val_y2_output_root_mean_squared_error: 1.1462
# Epoch 161/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9409 - y1_output_root_mean_squared_error: 0.6821 - y2_output_root_mean_squared_error: 1.1900 - val_loss: 2.8490 - val_y1_output_root_mean_squared_error: 0.7019 - val_y2_output_root_mean_squared_error: 1.5350
# Epoch 162/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9542 - y1_output_root_mean_squared_error: 0.6920 - y2_output_root_mean_squared_error: 1.1953 - val_loss: 2.3469 - val_y1_output_root_mean_squared_error: 0.8687 - val_y2_output_root_mean_squared_error: 1.2618
# Epoch 163/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0846 - y1_output_root_mean_squared_error: 0.5564 - y2_output_root_mean_squared_error: 0.8759 - val_loss: 1.6418 - val_y1_output_root_mean_squared_error: 0.5909 - val_y2_output_root_mean_squared_error: 1.1369
# Epoch 164/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4655 - y1_output_root_mean_squared_error: 0.5443 - y2_output_root_mean_squared_error: 1.0757 - val_loss: 1.2581 - val_y1_output_root_mean_squared_error: 0.4861 - val_y2_output_root_mean_squared_error: 1.0108
# Epoch 165/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6024 - y1_output_root_mean_squared_error: 0.6077 - y2_output_root_mean_squared_error: 1.0993 - val_loss: 3.7232 - val_y1_output_root_mean_squared_error: 0.9534 - val_y2_output_root_mean_squared_error: 1.6776
# Epoch 166/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9680 - y1_output_root_mean_squared_error: 0.6821 - y2_output_root_mean_squared_error: 1.2227 - val_loss: 1.2834 - val_y1_output_root_mean_squared_error: 0.5100 - val_y2_output_root_mean_squared_error: 1.0116
# Epoch 167/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0680 - y1_output_root_mean_squared_error: 0.4646 - y2_output_root_mean_squared_error: 0.9186 - val_loss: 2.4063 - val_y1_output_root_mean_squared_error: 0.8229 - val_y2_output_root_mean_squared_error: 1.3149
# Epoch 168/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.0650 - y1_output_root_mean_squared_error: 0.7281 - y2_output_root_mean_squared_error: 1.2343 - val_loss: 2.0657 - val_y1_output_root_mean_squared_error: 0.7486 - val_y2_output_root_mean_squared_error: 1.2269
# Epoch 169/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4702 - y1_output_root_mean_squared_error: 0.6244 - y2_output_root_mean_squared_error: 1.0338 - val_loss: 1.4323 - val_y1_output_root_mean_squared_error: 0.5440 - val_y2_output_root_mean_squared_error: 1.0660
# Epoch 170/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2036 - y1_output_root_mean_squared_error: 0.5688 - y2_output_root_mean_squared_error: 0.9362 - val_loss: 1.4929 - val_y1_output_root_mean_squared_error: 0.5761 - val_y2_output_root_mean_squared_error: 1.0775
# Epoch 171/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9491 - y1_output_root_mean_squared_error: 0.4322 - y2_output_root_mean_squared_error: 0.8684 - val_loss: 3.2481 - val_y1_output_root_mean_squared_error: 0.8522 - val_y2_output_root_mean_squared_error: 1.5880
# Epoch 172/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3912 - y1_output_root_mean_squared_error: 0.5612 - y2_output_root_mean_squared_error: 1.0221 - val_loss: 1.6053 - val_y1_output_root_mean_squared_error: 0.6157 - val_y2_output_root_mean_squared_error: 1.1073
# Epoch 173/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6062 - y1_output_root_mean_squared_error: 0.6124 - y2_output_root_mean_squared_error: 1.0976 - val_loss: 4.7981 - val_y1_output_root_mean_squared_error: 1.2029 - val_y2_output_root_mean_squared_error: 1.8306
# Epoch 174/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5244 - y1_output_root_mean_squared_error: 0.5836 - y2_output_root_mean_squared_error: 1.0855 - val_loss: 1.2450 - val_y1_output_root_mean_squared_error: 0.4942 - val_y2_output_root_mean_squared_error: 1.0004
# Epoch 175/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2811 - y1_output_root_mean_squared_error: 0.5233 - y2_output_root_mean_squared_error: 1.0019 - val_loss: 1.5641 - val_y1_output_root_mean_squared_error: 0.6135 - val_y2_output_root_mean_squared_error: 1.0898
# Epoch 176/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1841 - y1_output_root_mean_squared_error: 0.5421 - y2_output_root_mean_squared_error: 0.9418 - val_loss: 3.6972 - val_y1_output_root_mean_squared_error: 1.2871 - val_y2_output_root_mean_squared_error: 1.4285
# Epoch 177/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5486 - y1_output_root_mean_squared_error: 0.6310 - y2_output_root_mean_squared_error: 1.0634 - val_loss: 1.6754 - val_y1_output_root_mean_squared_error: 0.5708 - val_y2_output_root_mean_squared_error: 1.1617
# Epoch 178/500
# ...
# Epoch 442/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5145 - y1_output_root_mean_squared_error: 0.3861 - y2_output_root_mean_squared_error: 0.6003 - val_loss: 0.8961 - val_y1_output_root_mean_squared_error: 0.3869 - val_y2_output_root_mean_squared_error: 0.8639
# Epoch 443/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3850 - y1_output_root_mean_squared_error: 0.3495 - y2_output_root_mean_squared_error: 0.5105 - val_loss: 0.8433 - val_y1_output_root_mean_squared_error: 0.5170 - val_y2_output_root_mean_squared_error: 0.7589
# Epoch 444/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4918 - y1_output_root_mean_squared_error: 0.3861 - y2_output_root_mean_squared_error: 0.5837 - val_loss: 2.0993 - val_y1_output_root_mean_squared_error: 0.6878 - val_y2_output_root_mean_squared_error: 1.2752
# Epoch 445/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4532 - y1_output_root_mean_squared_error: 0.3761 - y2_output_root_mean_squared_error: 0.5557 - val_loss: 1.2157 - val_y1_output_root_mean_squared_error: 0.5609 - val_y2_output_root_mean_squared_error: 0.9492
# Epoch 446/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4142 - y1_output_root_mean_squared_error: 0.3651 - y2_output_root_mean_squared_error: 0.5248 - val_loss: 0.8983 - val_y1_output_root_mean_squared_error: 0.4060 - val_y2_output_root_mean_squared_error: 0.8564
# Epoch 447/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3309 - y1_output_root_mean_squared_error: 0.3445 - y2_output_root_mean_squared_error: 0.4594 - val_loss: 0.6578 - val_y1_output_root_mean_squared_error: 0.3789 - val_y2_output_root_mean_squared_error: 0.7171
# Epoch 448/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3360 - y1_output_root_mean_squared_error: 0.3380 - y2_output_root_mean_squared_error: 0.4698 - val_loss: 0.7667 - val_y1_output_root_mean_squared_error: 0.3904 - val_y2_output_root_mean_squared_error: 0.7837
# Epoch 449/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6000 - y1_output_root_mean_squared_error: 0.4202 - y2_output_root_mean_squared_error: 0.6281 - val_loss: 1.2443 - val_y1_output_root_mean_squared_error: 0.4589 - val_y2_output_root_mean_squared_error: 1.0167
# Epoch 450/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4165 - y1_output_root_mean_squared_error: 0.3310 - y2_output_root_mean_squared_error: 0.5481 - val_loss: 1.3619 - val_y1_output_root_mean_squared_error: 0.3705 - val_y2_output_root_mean_squared_error: 1.1066
# Epoch 451/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4737 - y1_output_root_mean_squared_error: 0.3786 - y2_output_root_mean_squared_error: 0.5710 - val_loss: 0.9335 - val_y1_output_root_mean_squared_error: 0.4007 - val_y2_output_root_mean_squared_error: 0.8792
# Epoch 452/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3660 - y1_output_root_mean_squared_error: 0.3019 - y2_output_root_mean_squared_error: 0.5205 - val_loss: 0.9412 - val_y1_output_root_mean_squared_error: 0.4525 - val_y2_output_root_mean_squared_error: 0.8582
# Epoch 453/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3582 - y1_output_root_mean_squared_error: 0.3405 - y2_output_root_mean_squared_error: 0.4900 - val_loss: 0.7497 - val_y1_output_root_mean_squared_error: 0.4623 - val_y2_output_root_mean_squared_error: 0.7321
# Epoch 454/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3946 - y1_output_root_mean_squared_error: 0.3238 - y2_output_root_mean_squared_error: 0.5318 - val_loss: 0.7047 - val_y1_output_root_mean_squared_error: 0.4186 - val_y2_output_root_mean_squared_error: 0.7276
# Epoch 455/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3413 - y1_output_root_mean_squared_error: 0.3203 - y2_output_root_mean_squared_error: 0.4863 - val_loss: 0.6689 - val_y1_output_root_mean_squared_error: 0.4095 - val_y2_output_root_mean_squared_error: 0.7080
# Epoch 456/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3035 - y1_output_root_mean_squared_error: 0.3229 - y2_output_root_mean_squared_error: 0.4438 - val_loss: 0.8551 - val_y1_output_root_mean_squared_error: 0.4953 - val_y2_output_root_mean_squared_error: 0.7808
# Epoch 457/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3924 - y1_output_root_mean_squared_error: 0.3598 - y2_output_root_mean_squared_error: 0.5114 - val_loss: 0.8644 - val_y1_output_root_mean_squared_error: 0.4588 - val_y2_output_root_mean_squared_error: 0.8086
# Epoch 458/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3509 - y1_output_root_mean_squared_error: 0.3249 - y2_output_root_mean_squared_error: 0.4932 - val_loss: 0.7280 - val_y1_output_root_mean_squared_error: 0.3747 - val_y2_output_root_mean_squared_error: 0.7665
# Epoch 459/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3524 - y1_output_root_mean_squared_error: 0.3277 - y2_output_root_mean_squared_error: 0.4928 - val_loss: 0.9570 - val_y1_output_root_mean_squared_error: 0.6316 - val_y2_output_root_mean_squared_error: 0.7471
# Epoch 460/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3769 - y1_output_root_mean_squared_error: 0.3875 - y2_output_root_mean_squared_error: 0.4726 - val_loss: 1.4433 - val_y1_output_root_mean_squared_error: 0.6542 - val_y2_output_root_mean_squared_error: 1.0076
# Epoch 461/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4085 - y1_output_root_mean_squared_error: 0.3853 - y2_output_root_mean_squared_error: 0.5050 - val_loss: 0.7521 - val_y1_output_root_mean_squared_error: 0.4631 - val_y2_output_root_mean_squared_error: 0.7332
# Epoch 462/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3756 - y1_output_root_mean_squared_error: 0.3226 - y2_output_root_mean_squared_error: 0.5182 - val_loss: 0.7306 - val_y1_output_root_mean_squared_error: 0.4270 - val_y2_output_root_mean_squared_error: 0.7404
# Epoch 463/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3673 - y1_output_root_mean_squared_error: 0.3240 - y2_output_root_mean_squared_error: 0.5111 - val_loss: 0.6602 - val_y1_output_root_mean_squared_error: 0.3929 - val_y2_output_root_mean_squared_error: 0.7112
# Epoch 464/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3285 - y1_output_root_mean_squared_error: 0.3226 - y2_output_root_mean_squared_error: 0.4725 - val_loss: 1.2445 - val_y1_output_root_mean_squared_error: 0.6301 - val_y2_output_root_mean_squared_error: 0.9206
# Epoch 465/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6186 - y1_output_root_mean_squared_error: 0.4426 - y2_output_root_mean_squared_error: 0.6468 - val_loss: 0.7390 - val_y1_output_root_mean_squared_error: 0.4373 - val_y2_output_root_mean_squared_error: 0.7401
# Epoch 466/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3074 - y1_output_root_mean_squared_error: 0.3140 - y2_output_root_mean_squared_error: 0.4507 - val_loss: 0.7999 - val_y1_output_root_mean_squared_error: 0.4425 - val_y2_output_root_mean_squared_error: 0.7772
# Epoch 467/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3557 - y1_output_root_mean_squared_error: 0.3358 - y2_output_root_mean_squared_error: 0.4917 - val_loss: 0.8473 - val_y1_output_root_mean_squared_error: 0.4340 - val_y2_output_root_mean_squared_error: 0.8117
# Epoch 468/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4410 - y1_output_root_mean_squared_error: 0.3621 - y2_output_root_mean_squared_error: 0.5485 - val_loss: 0.8031 - val_y1_output_root_mean_squared_error: 0.4140 - val_y2_output_root_mean_squared_error: 0.7948
# Epoch 469/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4484 - y1_output_root_mean_squared_error: 0.3361 - y2_output_root_mean_squared_error: 0.5723 - val_loss: 0.7886 - val_y1_output_root_mean_squared_error: 0.4406 - val_y2_output_root_mean_squared_error: 0.7711
# Epoch 470/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3651 - y1_output_root_mean_squared_error: 0.3585 - y2_output_root_mean_squared_error: 0.4844 - val_loss: 4.1902 - val_y1_output_root_mean_squared_error: 0.5526 - val_y2_output_root_mean_squared_error: 1.9710
# Epoch 471/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6843 - y1_output_root_mean_squared_error: 0.3823 - y2_output_root_mean_squared_error: 0.6986 - val_loss: 0.8828 - val_y1_output_root_mean_squared_error: 0.4342 - val_y2_output_root_mean_squared_error: 0.8332
# Epoch 472/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4307 - y1_output_root_mean_squared_error: 0.3861 - y2_output_root_mean_squared_error: 0.5297 - val_loss: 0.6602 - val_y1_output_root_mean_squared_error: 0.4217 - val_y2_output_root_mean_squared_error: 0.6946
# Epoch 473/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3242 - y1_output_root_mean_squared_error: 0.3422 - y2_output_root_mean_squared_error: 0.4522 - val_loss: 0.7032 - val_y1_output_root_mean_squared_error: 0.4049 - val_y2_output_root_mean_squared_error: 0.7344
# Epoch 474/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3351 - y1_output_root_mean_squared_error: 0.3295 - y2_output_root_mean_squared_error: 0.4739 - val_loss: 0.6866 - val_y1_output_root_mean_squared_error: 0.3983 - val_y2_output_root_mean_squared_error: 0.7267
# Epoch 475/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4991 - y1_output_root_mean_squared_error: 0.3800 - y2_output_root_mean_squared_error: 0.5887 - val_loss: 0.7716 - val_y1_output_root_mean_squared_error: 0.4468 - val_y2_output_root_mean_squared_error: 0.7563
# Epoch 476/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3539 - y1_output_root_mean_squared_error: 0.3309 - y2_output_root_mean_squared_error: 0.4930 - val_loss: 0.6480 - val_y1_output_root_mean_squared_error: 0.4212 - val_y2_output_root_mean_squared_error: 0.6859
# Epoch 477/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2954 - y1_output_root_mean_squared_error: 0.3196 - y2_output_root_mean_squared_error: 0.4385 - val_loss: 0.8123 - val_y1_output_root_mean_squared_error: 0.4011 - val_y2_output_root_mean_squared_error: 0.8071
# Epoch 478/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3110 - y1_output_root_mean_squared_error: 0.3064 - y2_output_root_mean_squared_error: 0.4640 - val_loss: 0.6996 - val_y1_output_root_mean_squared_error: 0.4898 - val_y2_output_root_mean_squared_error: 0.6780
# Epoch 479/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3027 - y1_output_root_mean_squared_error: 0.3416 - y2_output_root_mean_squared_error: 0.4297 - val_loss: 0.6643 - val_y1_output_root_mean_squared_error: 0.3720 - val_y2_output_root_mean_squared_error: 0.7252
# Epoch 480/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3651 - y1_output_root_mean_squared_error: 0.3396 - y2_output_root_mean_squared_error: 0.4865 - val_loss: 0.6691 - val_y1_output_root_mean_squared_error: 0.3992 - val_y2_output_root_mean_squared_error: 0.7140
# Epoch 481/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.5523 - y1_output_root_mean_squared_error: 1.0091 - y2_output_root_mean_squared_error: 1.7584 - val_loss: 0.6713 - val_y1_output_root_mean_squared_error: 0.4026 - val_y2_output_root_mean_squared_error: 0.7136
# Epoch 482/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3582 - y1_output_root_mean_squared_error: 0.3450 - y2_output_root_mean_squared_error: 0.4846 - val_loss: 0.9271 - val_y1_output_root_mean_squared_error: 0.3850 - val_y2_output_root_mean_squared_error: 0.8825
# Epoch 483/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3035 - y1_output_root_mean_squared_error: 0.3141 - y2_output_root_mean_squared_error: 0.4497 - val_loss: 0.6778 - val_y1_output_root_mean_squared_error: 0.4064 - val_y2_output_root_mean_squared_error: 0.7160
# Epoch 484/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4055 - y1_output_root_mean_squared_error: 0.3209 - y2_output_root_mean_squared_error: 0.5351 - val_loss: 0.7659 - val_y1_output_root_mean_squared_error: 0.4790 - val_y2_output_root_mean_squared_error: 0.7324
# Epoch 485/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3824 - y1_output_root_mean_squared_error: 0.3778 - y2_output_root_mean_squared_error: 0.4850 - val_loss: 0.7670 - val_y1_output_root_mean_squared_error: 0.4119 - val_y2_output_root_mean_squared_error: 0.7729
# Epoch 486/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4715 - y1_output_root_mean_squared_error: 0.3768 - y2_output_root_mean_squared_error: 0.5691 - val_loss: 0.7428 - val_y1_output_root_mean_squared_error: 0.4088 - val_y2_output_root_mean_squared_error: 0.7587
# Epoch 487/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3305 - y1_output_root_mean_squared_error: 0.3448 - y2_output_root_mean_squared_error: 0.4566 - val_loss: 1.0288 - val_y1_output_root_mean_squared_error: 0.5392 - val_y2_output_root_mean_squared_error: 0.8591
# Epoch 488/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3616 - y1_output_root_mean_squared_error: 0.3543 - y2_output_root_mean_squared_error: 0.4841 - val_loss: 0.7088 - val_y1_output_root_mean_squared_error: 0.4221 - val_y2_output_root_mean_squared_error: 0.7284
# Epoch 489/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2870 - y1_output_root_mean_squared_error: 0.3120 - y2_output_root_mean_squared_error: 0.4284 - val_loss: 0.9513 - val_y1_output_root_mean_squared_error: 0.4871 - val_y2_output_root_mean_squared_error: 0.8450
# Epoch 490/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9925 - y1_output_root_mean_squared_error: 0.4760 - y2_output_root_mean_squared_error: 0.8530 - val_loss: 0.8400 - val_y1_output_root_mean_squared_error: 0.4729 - val_y2_output_root_mean_squared_error: 0.7851
# Epoch 491/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3352 - y1_output_root_mean_squared_error: 0.3280 - y2_output_root_mean_squared_error: 0.4726 - val_loss: 0.7070 - val_y1_output_root_mean_squared_error: 0.4247 - val_y2_output_root_mean_squared_error: 0.7257
# Epoch 492/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2880 - y1_output_root_mean_squared_error: 0.3187 - y2_output_root_mean_squared_error: 0.4307 - val_loss: 0.7298 - val_y1_output_root_mean_squared_error: 0.4092 - val_y2_output_root_mean_squared_error: 0.7499
# Epoch 493/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3312 - y1_output_root_mean_squared_error: 0.3119 - y2_output_root_mean_squared_error: 0.4809 - val_loss: 0.6550 - val_y1_output_root_mean_squared_error: 0.3593 - val_y2_output_root_mean_squared_error: 0.7252
# Epoch 494/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3122 - y1_output_root_mean_squared_error: 0.3684 - y2_output_root_mean_squared_error: 0.4175 - val_loss: 1.4283 - val_y1_output_root_mean_squared_error: 0.6394 - val_y2_output_root_mean_squared_error: 1.0097
# Epoch 495/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3497 - y1_output_root_mean_squared_error: 0.3292 - y2_output_root_mean_squared_error: 0.4896 - val_loss: 0.9974 - val_y1_output_root_mean_squared_error: 0.5469 - val_y2_output_root_mean_squared_error: 0.8357
# Epoch 496/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3604 - y1_output_root_mean_squared_error: 0.3411 - y2_output_root_mean_squared_error: 0.4913 - val_loss: 1.1480 - val_y1_output_root_mean_squared_error: 0.5190 - val_y2_output_root_mean_squared_error: 0.9374
# Epoch 497/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3460 - y1_output_root_mean_squared_error: 0.3556 - y2_output_root_mean_squared_error: 0.4660 - val_loss: 1.2293 - val_y1_output_root_mean_squared_error: 0.5382 - val_y2_output_root_mean_squared_error: 0.9693
# Epoch 498/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3750 - y1_output_root_mean_squared_error: 0.3536 - y2_output_root_mean_squared_error: 0.4983 - val_loss: 0.6903 - val_y1_output_root_mean_squared_error: 0.4227 - val_y2_output_root_mean_squared_error: 0.7153
# Epoch 499/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3190 - y1_output_root_mean_squared_error: 0.3592 - y2_output_root_mean_squared_error: 0.4319 - val_loss: 0.9575 - val_y1_output_root_mean_squared_error: 0.4106 - val_y2_output_root_mean_squared_error: 0.8882
# Epoch 500/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3029 - y1_output_root_mean_squared_error: 0.3253 - y2_output_root_mean_squared_error: 0.4419 - val_loss: 0.7517 - val_y1_output_root_mean_squared_error: 0.4467 - val_y2_output_root_mean_squared_error: 0.7431

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss = model.evaluate(x=norm_test_X, y=test_Y)

# Extract the RMSE values from the history object
Y1_rmse = history.history['y1_output_root_mean_squared_error'][-1]
Y2_rmse = history.history['y2_output_root_mean_squared_error'][-1]

print("Loss = {}, Y1_loss = {}, Y1_rmse = {}, Y2_loss = {}, Y2_rmse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.7442 - y1_output_root_mean_squared_error: 0.4041 - y2_output_root_mean_squared_error: 0.7600
# Loss = 0.7517454028129578, Y1_loss = 0.4467199444770813, Y1_rmse = 0.3468785881996155, Y2_loss = 0.7430926561355591, Y2_rmse = 0.4628858268260956

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
