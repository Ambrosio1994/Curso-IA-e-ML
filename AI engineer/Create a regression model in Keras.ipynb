# %%
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import numpy as np

# %%
path = "/content/concrete_data.csv"
data = pd.read_csv(path)
data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %%
data.duplicated().sum()
# Out:
# 25

# %%
data.drop_duplicates(inplace=True)

# %% [markdown]
# # **Part A**

# %%
features = data.iloc[:,:-1].values
target = data.iloc[:,-1].values

# %%
X_train, X_test, y_train, y_test = train_test_split(
    features, target,
    test_size=0.3, random_state=42
    )

# %%
def baseline_model():
  model = tf.keras.Sequential([
    layers.Dense(10, activation='relu', input_shape=[features.shape[1]]),
    layers.Dense(1)
  ])

  model.compile(loss='mean_squared_error', optimizer='adam')

  return model

# %%
# List to store mean squared errors
mse_scores = []

for i in range(50):
    # Create the model
    model = baseline_model()

    # Train the model on training data
    model.fit(X_train, y_train, epochs=50, verbose=0)

    # Evaluate the model on test data
    y_pred = model.predict(X_test)

    # Calculate the mean squared error
    mse = mean_squared_error(y_test, y_pred)

    # Store the mean squared error in the list
    mse_scores.append(mse)

# Calculate the mean and standard deviation of the mean squared errors
mean_mse = np.mean(mse_scores)
std_mse = np.std(mse_scores)

# Print the results
print("Average mean squared errors:", mean_mse)
print("Standard deviation of mean squared errors:", std_mse)
# Out:
# 10/10 [==============================] - 0s 6ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 3ms/step
# Average mean squared errors: 437.6591492707882
# Standard deviation of mean squared errors: 400.76988276516624

# %% [markdown]
# # **Part B**

# %%
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# List to store mean squared errors
mse_scores = []

for i in range(50):
    # Create the model
    model = baseline_model()

    # Train the model on training data
    model.fit(X_train, y_train, epochs=50, verbose=0)

    # Evaluate the model on test data
    y_pred = model.predict(X_test)

    # Calculate the mean squared error
    mse = mean_squared_error(y_test, y_pred)

    # Store the mean squared error in the list
    mse_scores.append(mse)

# Calculate the mean and standard deviation of the mean squared errors
mean_mse = np.mean(mse_scores)
std_mse = np.std(mse_scores)

# Print the results
print("Average mean squared errors:", mean_mse)
print("Standard deviation of mean squared errors:", std_mse)
# Out:
# 10/10 [==============================] - 0s 10ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# Average mean squared errors: 269.7400325587649
# Standard deviation of mean squared errors: 25.158736580700925

# %% [markdown]
# # **Part C**

# %%
# List to store mean squared errors
mse_scores = []

for i in range(50):
    # Create the model
    model = baseline_model()

    # Train the model on training data
    model.fit(X_train, y_train, epochs=100, verbose=0)

    # Evaluate the model on test data
    y_pred = model.predict(X_test)

    # Calculate the mean squared error
    mse = mean_squared_error(y_test, y_pred)

    # Store the mean squared error in the list
    mse_scores.append(mse)

# Calculate the mean and standard deviation of the mean squared errors
mean_mse = np.mean(mse_scores)
std_mse = np.std(mse_scores)

# Print the results
print("Average mean squared errors:", mean_mse)
print("Standard deviation of mean squared errors:", std_mse)
# Out:
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 4ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# Average mean squared errors: 208.6192949161331
# Standard deviation of mean squared errors: 22.99746156319581

# %% [markdown]
# # **Part D**

# %%
def baseline_model():
  model = tf.keras.Sequential([
    layers.Dense(10, activation='relu', input_shape=[features.shape[1]]),
    layers.Dense(10, activation='relu'),
    layers.Dense(10, activation='relu'),
    layers.Dense(1)
  ])

  model.compile(loss='mean_squared_error', optimizer='adam')

  return model

# List to store mean squared errors
mse_scores = []

for i in range(50):
    # Create the model
    model = baseline_model()

    # Train the model on training data
    model.fit(X_train, y_train, epochs=50, verbose=0)

    # Evaluate the model on test data
    y_pred = model.predict(X_test)

    # Calculate the mean squared error
    mse = mean_squared_error(y_test, y_pred)

    # Store the mean squared error in the list
    mse_scores.append(mse)

# Calculate the mean and standard deviation of the mean squared errors
mean_mse = np.mean(mse_scores)
std_mse = np.std(mse_scores)

# Print the results
print("Average mean squared errors:", mean_mse)
print("Standard deviation of mean squared errors:", std_mse)
# Out:
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 6ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# Average mean squared errors: 135.55793043965775
# Standard deviation of mean squared errors: 11.127553809214755
